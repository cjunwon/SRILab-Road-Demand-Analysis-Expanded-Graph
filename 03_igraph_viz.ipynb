# %%
# import intermediate_files/igraph.pickle

import pickle
import igraph as ig
import matplotlib.pyplot as plt

# Load the graph
with open('intermediate_files/igraph.pickle', 'rb') as f:
    g = pickle.load(f)

# %%
fig, ax = plt.subplots()
ig.plot(g, target=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /var/folders/6m/88dwrhnx7m3cybxwl1p0rtq40000gn/T/ipykernel_71895/2849474042.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ig.plot(g, target=ax)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/igraph/drawing/__init__.py in plot(obj, target, bbox, *args, **kwds)
#     265             return
#     266         else:
# --> 267             result = plotter(
#     268                 backend,
#     269                 target,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/igraph/drawing/graph.py in __plot__(self, backend, context, *args, **kwds)
#     559         DrawerDirectory.resolve(self, backend)(context),
#     560     )
# ...
